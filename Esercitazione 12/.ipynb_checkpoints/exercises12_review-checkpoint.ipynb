# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # CNN

# %% [markdown]
# ## Exercise 12.1

# %% [markdown]
# ### Adam

# %% [markdown]
# First test changing optimizer with Adam(): final accuracy=0.978. It produces a good model but overfitting is present after 7 epochs.

# %% [markdown]
# ![loss_test_adam.png](data:image/png;base64,...)![acc_test_adam.png](data:image/png;base64,...)

# %% [markdown]
# ### Adamax

# %% [markdown]
# Test with Adamax(): final accuracy=0.983.Better than the previous without overfitting in 20 epochs and better final accuracy.

# %% [markdown]
# ![loss_test_adamax.png](data:image/png;base64,...)![acc_test_adamax.png](data:image/png;base64,...)

# %% [markdown]
# ### SGD

# %% [markdown]
# Final test with SGD is the best beacause loss functions and accuracy are more regular and it implies that the model is learning true information and can perform better with more images and more epochs, but after 20 epochs accuracy=0.975

# %% [markdown]
# ![loss_test_sgd.png](data:image/png;base64,...)![acc_test_sgd.png](data:image/png;base64,...)

# %% [markdown]
# # Exercise 12.2/12.3

# %% [markdown]
# The proposed CNN has been ispired by another project of classification on which I'm working: this Net is built aplliyng a pooling layers after any convolution one and number of filters increases with layers. In this way, it tries to take advantage from all the symmetries of images sets. At the end there are a dense layer, a dropout to prevent overfitting, a flatten one and a softmax because of categorical classification.
#
# Overfitting is not evident in 50 epochs and a good accuracy is performed (99%)

# %% [markdown]
# ![history.png](data:image/png;base64,...)![acc.png](data:image/png;base64,...)

# %% [markdown]
# ![plot_sample.png](data:image/png;base64,...)

# %% [markdown]
# Numbers written by me are well predicted but 6 which is labelled as 5

# %% [markdown]
# ![zero.png](data:image/png;base64,...)![two.png](data:image/png;base64,...)![six.png](data:image/png;base64,...)![seven.png](data:image/png;base64,...)![one.png](data:image/png;base64,...)![nine.png](data:image/png;base64,...)![four.png](data:image/png;base64,...)![five.png](data:image/png;base64,...)![eight.png](data:image/png;base64,...)![3.png](data:image/png;base64,...)
